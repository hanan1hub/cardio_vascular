# %%
import os
import numpy as np
import pandas as pd
import librosa
import librosa.feature
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Set the paths to your data directories and labels files
train_data_dir = '/content/drive/MyDrive/Heart-Multiclass/DeepSignal/TrainData'
train_labels_file = '/content/drive/MyDrive/Heart-Multiclass/DeepSignal/TrainLabels.xlsx'
test_data_dir = '/content/drive/MyDrive/Heart-Multiclass/DeepSignal/TestData'
test_labels_file = '/content/drive/MyDrive/Heart-Multiclass/DeepSignal/TestLabel.xlsx'

def specificity(y_true, y_pred):
    conf_matrix = confusion_matrix(y_true, y_pred)
    fp = conf_matrix.sum(axis=0) - np.diag(conf_matrix)
    tn = conf_matrix.sum() - (conf_matrix.sum(axis=1) + fp)
    specificity = tn / (tn+fp)
    return np.mean(specificity)

# Modify the load_data function
def load_data(data_dir, labels_file):
    labels_df = pd.read_excel(labels_file)
    data = []
    labels = []

    for file_name in os.listdir(data_dir):
        if file_name.endswith('.wav'):
            file_path = os.path.join(data_dir, file_name)
            signal, sr = librosa.load(file_path, sr=None, duration=3.0)

            mfccs = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13)

            matching_rows = labels_df.loc[labels_df['Name'] == file_name]
            if len(matching_rows) > 0:
                label = matching_rows['Label'].values[0]
                data.append(mfccs)
                labels.append(label)

    return data, labels

# Load training and test data
train_data, train_labels = load_data(train_data_dir, train_labels_file)
test_data, test_labels = load_data(test_data_dir, test_labels_file)

# Convert MFCCs to numpy arrays
train_data_mfccs = np.array(train_data)
test_data_mfccs = np.array(test_data)

# Reshape the data for Conv1D
train_data_mfccs = np.expand_dims(train_data_mfccs, axis=3)  # Add an extra dimension for Conv1D
test_data_mfccs = np.expand_dims(test_data_mfccs, axis=3)

# Update the input_shape to match the shape of MFCCs
input_shape = train_data_mfccs.shape[1:]  # Shape without the number of samples

# Convert labels to numeric format
label_encoder = LabelEncoder()
encoded_train_labels = label_encoder.fit_transform(train_labels)
encoded_test_labels = label_encoder.transform(test_labels)

num_classes = len(label_encoder.classes_)

# Determine the maximum length of signals
max_length = max(max(len(signal) for signal in train_data), max(len(signal) for signal in test_data))

# Prepare the data
train_data = np.array([np.pad(signal, (0, max_length - len(signal)), constant_values=0) for signal in train_data])
test_data = np.array([np.pad(signal, (0, max_length - len(signal)), constant_values=0) for signal in test_data])

train_data = np.expand_dims(train_data, axis=2)
test_data = np.expand_dims(test_data, axis=2)

train_labels = to_categorical(encoded_train_labels, num_classes=num_classes)
test_labels = to_categorical(encoded_test_labels, num_classes=num_classes)

# Prepare cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize results
train_acc_results = []
val_acc_results = []
test_acc_results = []
sensitivity_results = []
specificity_results = []
f1_score_results = []

# Loop over each fold
for fold, (train_index, test_index) in enumerate(kf.split(train_data_mfccs, encoded_train_labels)):
    X_train, X_test = train_data_mfccs[train_index], train_data_mfccs[test_index]
    y_train, y_test = train_labels[train_index], train_labels[test_index]

    model = Sequential()
    input_shape = X_train.shape[1:]  # Shape without the number of samples
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))  # Add another Conv1D layer
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))  # Add another Conv1D layer
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))  # Add another Conv1D layer
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))  # Add another Conv1D layer
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))  # Add another Conv1D layer
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))  # Add another Conv1D layer
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))  # Add another Conv1D layer
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(16, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(num_classes, activation='softmax'))

    # Compile the model
    learning_rate = 0.00001
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    # Define early stopping to prevent overfitting
    early_stopping = EarlyStopping(monitor='val_loss', patience=5)

    # Train the model
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=8, epochs=1000, callbacks=[early_stopping], verbose=1)

    # Get the training and validation accuracy from history
    final_training_accuracy = history.history['accuracy'][-1]
    final_val_accuracy = history.history['val_accuracy'][-1]

    # Get the training and test accuracy from history
    final_training_accuracy = history.history['accuracy'][-1]
    final_test_accuracy = history.history['val_accuracy'][-1]  # renamed from final_val_accuracy

    # Save the results
    train_acc_results.append(final_training_accuracy)
    val_acc_results.append(final_val_accuracy)

    # Save the results
    train_acc_results.append(final_training_accuracy)
    test_acc_results.append(final_test_accuracy)  # renamed from val_acc_results


    # Plot training and validation accuracy
    plt.figure(figsize=(8, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title(f'Training and Validation Accuracy for Fold {fold+1}')
    plt.legend()

    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(f'Training and Validation Loss for Fold {fold+1}')
    plt.legend()


    # Plot training, validation and test accuracy
    plt.figure(figsize=(8, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.plot(test_acc_results, label='Test Accuracy')  # Added this line
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title(f'Training, Validation, and Test Accuracy for Fold {fold+1}')
    plt.legend()

    plt.tight_layout()
    plt.show()


    # Compute and plot confusion matrix
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(y_test, axis=1)
    confusion_mat = confusion_matrix(y_test_classes, y_pred_classes)

    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion_mat, annot=True, fmt="d", cmap="Blues")
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title(f'Confusion Matrix for Fold {fold+1}')
    plt.show()

    # Compute and plot confusion matrix for test data
    y_pred = model.predict(test_data_mfccs)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(test_labels, axis=1)
    confusion_mat = confusion_matrix(y_test_classes, y_pred_classes)

    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion_mat, annot=True, fmt="d", cmap="Blues")
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title(f'Confusion Matrix for Test Data (Fold {fold+1})')
    plt.show()

    # Compute Sensitivity, Specificity, F1 Score
    sensitivity = recall_score(y_test_classes, y_pred_classes, average='micro')
    specificity_score = specificity(y_test_classes, y_pred_classes)  # renamed the variable
    f1 = f1_score(y_test_classes, y_pred_classes, average='micro')

    sensitivity_results.append(sensitivity)
    specificity_results.append(specificity_score)  # use the renamed variable
    f1_score_results.append(f1)



    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion_mat, annot=True, fmt="d", cmap="Blues")
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix for this Fold')
    plt.show()

    # Compute Sensitivity, Specificity, F1 Score for final test data
    sensitivity = recall_score(y_test_classes, y_pred_classes, average='micro')
    specificity_score = specificity(y_test_classes, y_pred_classes)
    f1 = f1_score(y_test_classes, y_pred_classes, average='micro')

    test_accuracy = accuracy_score(y_test_classes, y_pred_classes)
    test_acc_results.append(test_accuracy)

    print('Final Test Accuracy:', test_accuracy)
    print('Final Test Sensitivity:', sensitivity)
    print('Final Test Specificity:', specificity_score)
    print('Final Test F1 Score:', f1)

    print('Final training accuracy per fold:', train_acc_results)
    print('Final validation accuracy per fold:', val_acc_results)
    print('Final test accuracy per fold:', test_acc_results)
    print('Average final training accuracy:', np.mean(train_acc_results))
    print('Average final validation accuracy:', np.mean(val_acc_results))
    print('Average final test accuracy:', np.mean(test_acc_results))

    print('Final sensitivity per fold:', sensitivity_results)
    print('Final specificity per fold:', specificity_results)
    print('Final F1 score per fold:', f1_score_results)
    print('Average final sensitivity:', np.mean(sensitivity_results))
    print('Average final specificity:', np.mean(specificity_results))
    print('Average final F1 score:', np.mean(f1_score_results))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Epoch 1/1000
# 239/239 [==============================] - 8s 13ms/step - loss: 1.5284 - accuracy: 0.3197 - val_loss: 1.1063 - val_accuracy: 0.7631
# Epoch 2/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 1.1097 - accuracy: 0.5278 - val_loss: 0.6390 - val_accuracy: 0.8952
# Epoch 3/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.8316 - accuracy: 0.6688 - val_loss: 0.3998 - val_accuracy: 0.9245
# Epoch 4/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.6529 - accuracy: 0.7636 - val_loss: 0.2820 - val_accuracy: 0.9602
# Epoch 5/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.5526 - accuracy: 0.7925 - val_loss: 0.2120 - val_accuracy: 0.9539
# Epoch 6/1000
# 239/239 [==============================] - 2s 9ms/step - loss: 0.4660 - accuracy: 0.8187 - val_loss: 0.1624 - val_accuracy: 0.9706
# Epoch 7/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.4374 - accuracy: 0.8349 - val_loss: 0.1329 - val_accuracy: 0.9811
# Epoch 8/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.3717 - accuracy: 0.8574 - val_loss: 0.1117 - val_accuracy: 0.9790
# Epoch 9/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.3540 - accuracy: 0.8648 - val_loss: 0.0921 - val_accuracy: 0.9811
# Epoch 10/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.3150 - accuracy: 0.8884 - val_loss: 0.0626 - val_accuracy: 0.9895
# Epoch 11/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2895 - accuracy: 0.8952 - val_loss: 0.0595 - val_accuracy: 0.9916
# Epoch 12/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.2506 - accuracy: 0.9099 - val_loss: 0.0473 - val_accuracy: 0.9874
# Epoch 13/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2365 - accuracy: 0.9172 - val_loss: 0.0357 - val_accuracy: 0.9958
# Epoch 14/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.2443 - accuracy: 0.9135 - val_loss: 0.0421 - val_accuracy: 0.9979
# Epoch 15/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.2442 - accuracy: 0.9140 - val_loss: 0.0306 - val_accuracy: 0.9979
# Epoch 16/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.2343 - accuracy: 0.9140 - val_loss: 0.0330 - val_accuracy: 1.0000
# Epoch 17/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1989 - accuracy: 0.9271 - val_loss: 0.0239 - val_accuracy: 0.9958
# Epoch 18/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1968 - accuracy: 0.9329 - val_loss: 0.0140 - val_accuracy: 1.0000
# Epoch 19/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1689 - accuracy: 0.9423 - val_loss: 0.0147 - val_accuracy: 0.9979
# Epoch 20/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.2000 - accuracy: 0.9308 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 21/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1794 - accuracy: 0.9329 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 22/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1486 - accuracy: 0.9455 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 23/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1744 - accuracy: 0.9355 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 24/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1558 - accuracy: 0.9497 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 25/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1489 - accuracy: 0.9497 - val_loss: 0.0075 - val_accuracy: 0.9979
# Epoch 26/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1226 - accuracy: 0.9628 - val_loss: 0.0149 - val_accuracy: 0.9979
# Epoch 27/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1632 - accuracy: 0.9492 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 28/1000
# 239/239 [==============================] - 2s 9ms/step - loss: 0.1314 - accuracy: 0.9570 - val_loss: 0.0072 - val_accuracy: 0.9979
# Epoch 29/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1305 - accuracy: 0.9549 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 30/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1318 - accuracy: 0.9539 - val_loss: 0.0081 - val_accuracy: 0.9979
# Epoch 31/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1413 - accuracy: 0.9518 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 32/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1306 - accuracy: 0.9565 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 33/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1120 - accuracy: 0.9570 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 34/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1049 - accuracy: 0.9633 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 35/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1065 - accuracy: 0.9649 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 36/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1028 - accuracy: 0.9649 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 37/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.0911 - accuracy: 0.9722 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 38/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1004 - accuracy: 0.9638 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 39/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.0937 - accuracy: 0.9691 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 40/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1065 - accuracy: 0.9659 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 41/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.0978 - accuracy: 0.9654 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 42/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.0892 - accuracy: 0.9727 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 43/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.0997 - accuracy: 0.9680 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 44/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.0833 - accuracy: 0.9743 - val_loss: 0.0013 - val_accuracy: 1.0000
# 15/15 [==============================] - 1s 11ms/step
# 7/7 [==============================] - 0s 13ms/step
# Final Test Accuracy: 1.0
# Final Test Sensitivity: 1.0
# Final Test Specificity: 1.0
# Final Test F1 Score: 1.0
# Final training accuracy per fold: [0.9743186831474304, 0.9743186831474304]
# Final validation accuracy per fold: [1.0]
# Final test accuracy per fold: [1.0, 1.0]
# Average final training accuracy: 0.9743186831474304
# Average final validation accuracy: 1.0
# Average final test accuracy: 1.0
# Final sensitivity per fold: [1.0]
# Final specificity per fold: [1.0]
# Final F1 score per fold: [1.0]
# Average final sensitivity: 1.0
# Average final specificity: 1.0
# Average final F1 score: 1.0
# Epoch 1/1000
# 239/239 [==============================] - 8s 14ms/step - loss: 1.4693 - accuracy: 0.3606 - val_loss: 1.0772 - val_accuracy: 0.6268
# Epoch 2/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 1.0815 - accuracy: 0.5660 - val_loss: 0.7081 - val_accuracy: 0.7799
# Epoch 3/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.8534 - accuracy: 0.6667 - val_loss: 0.4967 - val_accuracy: 0.9140
# Epoch 4/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.6710 - accuracy: 0.7615 - val_loss: 0.3524 - val_accuracy: 0.9287
# Epoch 5/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.6133 - accuracy: 0.7877 - val_loss: 0.2891 - val_accuracy: 0.9308
# Epoch 6/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.5144 - accuracy: 0.8113 - val_loss: 0.2392 - val_accuracy: 0.9287
# Epoch 7/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.4512 - accuracy: 0.8485 - val_loss: 0.1906 - val_accuracy: 0.9497
# Epoch 8/1000
# 239/239 [==============================] - 3s 10ms/step - loss: 0.3723 - accuracy: 0.8810 - val_loss: 0.1307 - val_accuracy: 0.9644
# Epoch 9/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.3433 - accuracy: 0.8810 - val_loss: 0.1293 - val_accuracy: 0.9686
# Epoch 10/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.3263 - accuracy: 0.8905 - val_loss: 0.0843 - val_accuracy: 0.9748
# Epoch 11/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.2984 - accuracy: 0.8910 - val_loss: 0.0673 - val_accuracy: 0.9790
# Epoch 12/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2570 - accuracy: 0.9109 - val_loss: 0.0775 - val_accuracy: 0.9790
# Epoch 13/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.2437 - accuracy: 0.9177 - val_loss: 0.0617 - val_accuracy: 0.9811
# Epoch 14/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.2560 - accuracy: 0.9104 - val_loss: 0.0462 - val_accuracy: 0.9853
# Epoch 15/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.2173 - accuracy: 0.9224 - val_loss: 0.0453 - val_accuracy: 0.9895
# Epoch 16/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1977 - accuracy: 0.9345 - val_loss: 0.0309 - val_accuracy: 0.9958
# Epoch 17/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1885 - accuracy: 0.9345 - val_loss: 0.0316 - val_accuracy: 0.9937
# Epoch 18/1000
# 239/239 [==============================] - 3s 13ms/step - loss: 0.1772 - accuracy: 0.9460 - val_loss: 0.0283 - val_accuracy: 0.9895
# Epoch 19/1000
# 239/239 [==============================] - 3s 13ms/step - loss: 0.1724 - accuracy: 0.9418 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 20/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1589 - accuracy: 0.9444 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 21/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1461 - accuracy: 0.9534 - val_loss: 0.0186 - val_accuracy: 0.9958
# Epoch 22/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1516 - accuracy: 0.9476 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 23/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1537 - accuracy: 0.9460 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 24/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1534 - accuracy: 0.9450 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 25/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1540 - accuracy: 0.9486 - val_loss: 0.0189 - val_accuracy: 1.0000
# Epoch 26/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1081 - accuracy: 0.9612 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 27/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1171 - accuracy: 0.9570 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 28/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1403 - accuracy: 0.9523 - val_loss: 0.0075 - val_accuracy: 0.9979
# Epoch 29/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1164 - accuracy: 0.9612 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 30/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1014 - accuracy: 0.9680 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 31/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1061 - accuracy: 0.9607 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 32/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1063 - accuracy: 0.9680 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 33/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.0933 - accuracy: 0.9686 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 34/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.0887 - accuracy: 0.9701 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 35/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1056 - accuracy: 0.9633 - val_loss: 0.0059 - val_accuracy: 1.0000
# 15/15 [==============================] - 0s 6ms/step
# 7/7 [==============================] - 0s 6ms/step
# Final Test Accuracy: 0.9804878048780488
# Final Test Sensitivity: 0.9804878048780488
# Final Test Specificity: 0.9951219512195122
# Final Test F1 Score: 0.9804878048780488
# Final training accuracy per fold: [0.9743186831474304, 0.9743186831474304, 0.9633123874664307, 0.9633123874664307]
# Final validation accuracy per fold: [1.0, 1.0]
# Final test accuracy per fold: [1.0, 1.0, 1.0, 0.9804878048780488]
# Average final training accuracy: 0.9688155353069305
# Average final validation accuracy: 1.0
# Average final test accuracy: 0.9951219512195122
# Final sensitivity per fold: [1.0, 0.9804878048780488]
# Final specificity per fold: [1.0, 0.9951219512195122]
# Final F1 score per fold: [1.0, 0.9804878048780488]
# Average final sensitivity: 0.9902439024390244
# Average final specificity: 0.9975609756097561
# Average final F1 score: 0.9902439024390244
# Epoch 1/1000
# 239/239 [==============================] - 7s 13ms/step - loss: 1.4252 - accuracy: 0.3994 - val_loss: 0.9546 - val_accuracy: 0.6939
# Epoch 2/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 1.0178 - accuracy: 0.5891 - val_loss: 0.6418 - val_accuracy: 0.7966
# Epoch 3/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.8066 - accuracy: 0.6871 - val_loss: 0.4424 - val_accuracy: 0.8931
# Epoch 4/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.6548 - accuracy: 0.7521 - val_loss: 0.2728 - val_accuracy: 0.9434
# Epoch 5/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.5298 - accuracy: 0.8035 - val_loss: 0.2454 - val_accuracy: 0.9476
# Epoch 6/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.4537 - accuracy: 0.8375 - val_loss: 0.1784 - val_accuracy: 0.9686
# Epoch 7/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.4154 - accuracy: 0.8506 - val_loss: 0.1432 - val_accuracy: 0.9560
# Epoch 8/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.3834 - accuracy: 0.8569 - val_loss: 0.1079 - val_accuracy: 0.9748
# Epoch 9/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.3309 - accuracy: 0.8732 - val_loss: 0.1026 - val_accuracy: 0.9748
# Epoch 10/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.3294 - accuracy: 0.8784 - val_loss: 0.0713 - val_accuracy: 0.9958
# Epoch 11/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.2784 - accuracy: 0.8947 - val_loss: 0.0534 - val_accuracy: 0.9958
# Epoch 12/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2668 - accuracy: 0.9025 - val_loss: 0.0441 - val_accuracy: 0.9979
# Epoch 13/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2533 - accuracy: 0.9088 - val_loss: 0.0304 - val_accuracy: 1.0000
# Epoch 14/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2182 - accuracy: 0.9261 - val_loss: 0.0368 - val_accuracy: 0.9958
# Epoch 15/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1959 - accuracy: 0.9277 - val_loss: 0.0228 - val_accuracy: 1.0000
# Epoch 16/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2099 - accuracy: 0.9193 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 17/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1997 - accuracy: 0.9266 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 18/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1810 - accuracy: 0.9397 - val_loss: 0.0178 - val_accuracy: 1.0000
# Epoch 19/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1860 - accuracy: 0.9313 - val_loss: 0.0194 - val_accuracy: 1.0000
# Epoch 20/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1765 - accuracy: 0.9350 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 21/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1840 - accuracy: 0.9355 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 22/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2000 - accuracy: 0.9308 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 23/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1476 - accuracy: 0.9502 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 24/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1532 - accuracy: 0.9439 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 25/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1460 - accuracy: 0.9492 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 26/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1556 - accuracy: 0.9429 - val_loss: 0.0213 - val_accuracy: 0.9916
# Epoch 27/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1444 - accuracy: 0.9513 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 28/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1466 - accuracy: 0.9471 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 29/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1425 - accuracy: 0.9507 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 30/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1188 - accuracy: 0.9581 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 31/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1301 - accuracy: 0.9539 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 32/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1131 - accuracy: 0.9623 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 33/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1347 - accuracy: 0.9513 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 34/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1201 - accuracy: 0.9549 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 35/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1007 - accuracy: 0.9633 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 36/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.0989 - accuracy: 0.9665 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 37/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1071 - accuracy: 0.9602 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 38/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.0918 - accuracy: 0.9612 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 39/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1015 - accuracy: 0.9602 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 40/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1084 - accuracy: 0.9633 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 41/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.0929 - accuracy: 0.9644 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 42/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.0945 - accuracy: 0.9654 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 43/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.0892 - accuracy: 0.9654 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 44/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.0957 - accuracy: 0.9654 - val_loss: 0.0022 - val_accuracy: 1.0000
# 15/15 [==============================] - 1s 9ms/step
# 7/7 [==============================] - 0s 8ms/step
# Final Test Accuracy: 0.9951219512195122
# Final Test Sensitivity: 0.9951219512195122
# Final Test Specificity: 0.998780487804878
# Final Test F1 Score: 0.9951219512195122
# Final training accuracy per fold: [0.9743186831474304, 0.9743186831474304, 0.9633123874664307, 0.9633123874664307, 0.9654088020324707, 0.9654088020324707]
# Final validation accuracy per fold: [1.0, 1.0, 1.0]
# Final test accuracy per fold: [1.0, 1.0, 1.0, 0.9804878048780488, 1.0, 0.9951219512195122]
# Average final training accuracy: 0.9676799575487772
# Average final validation accuracy: 1.0
# Average final test accuracy: 0.9959349593495935
# Final sensitivity per fold: [1.0, 0.9804878048780488, 0.9951219512195122]
# Final specificity per fold: [1.0, 0.9951219512195122, 0.998780487804878]
# Final F1 score per fold: [1.0, 0.9804878048780488, 0.9951219512195122]
# Average final sensitivity: 0.991869918699187
# Average final specificity: 0.9979674796747968
# Average final F1 score: 0.991869918699187
# Epoch 1/1000
# 239/239 [==============================] - 8s 13ms/step - loss: 1.4717 - accuracy: 0.3669 - val_loss: 1.0724 - val_accuracy: 0.6478
# Epoch 2/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 1.0258 - accuracy: 0.6032 - val_loss: 0.4821 - val_accuracy: 0.8931
# Epoch 3/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.7529 - accuracy: 0.7133 - val_loss: 0.2945 - val_accuracy: 0.9099
# Epoch 4/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.5749 - accuracy: 0.7867 - val_loss: 0.2048 - val_accuracy: 0.9434
# Epoch 5/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.4872 - accuracy: 0.8166 - val_loss: 0.1601 - val_accuracy: 0.9644
# Epoch 6/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.4013 - accuracy: 0.8475 - val_loss: 0.1559 - val_accuracy: 0.9455
# Epoch 7/1000
# 239/239 [==============================] - 3s 10ms/step - loss: 0.3879 - accuracy: 0.8538 - val_loss: 0.0969 - val_accuracy: 0.9769
# Epoch 8/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.3422 - accuracy: 0.8732 - val_loss: 0.0692 - val_accuracy: 0.9832
# Epoch 9/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.3028 - accuracy: 0.8988 - val_loss: 0.0674 - val_accuracy: 0.9790
# Epoch 10/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2826 - accuracy: 0.9009 - val_loss: 0.0500 - val_accuracy: 0.9874
# Epoch 11/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2689 - accuracy: 0.8999 - val_loss: 0.0385 - val_accuracy: 0.9916
# Epoch 12/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2744 - accuracy: 0.8941 - val_loss: 0.0370 - val_accuracy: 0.9895
# Epoch 13/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2325 - accuracy: 0.9203 - val_loss: 0.0332 - val_accuracy: 0.9895
# Epoch 14/1000
# 239/239 [==============================] - 4s 15ms/step - loss: 0.2234 - accuracy: 0.9182 - val_loss: 0.0291 - val_accuracy: 0.9937
# Epoch 15/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.2201 - accuracy: 0.9167 - val_loss: 0.0257 - val_accuracy: 0.9895
# Epoch 16/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2108 - accuracy: 0.9256 - val_loss: 0.0202 - val_accuracy: 0.9916
# Epoch 17/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2104 - accuracy: 0.9161 - val_loss: 0.0198 - val_accuracy: 0.9937
# Epoch 18/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1874 - accuracy: 0.9224 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 19/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1875 - accuracy: 0.9261 - val_loss: 0.0147 - val_accuracy: 0.9979
# Epoch 20/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1708 - accuracy: 0.9361 - val_loss: 0.0162 - val_accuracy: 0.9916
# Epoch 21/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1640 - accuracy: 0.9298 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 22/1000
# 239/239 [==============================] - 3s 10ms/step - loss: 0.1588 - accuracy: 0.9371 - val_loss: 0.0117 - val_accuracy: 0.9979
# Epoch 23/1000
# 239/239 [==============================] - 3s 10ms/step - loss: 0.1641 - accuracy: 0.9366 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 24/1000
# 239/239 [==============================] - 2s 10ms/step - loss: 0.1287 - accuracy: 0.9581 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 25/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1535 - accuracy: 0.9439 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 26/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1114 - accuracy: 0.9596 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 27/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1362 - accuracy: 0.9476 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 28/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1574 - accuracy: 0.9429 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 29/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1441 - accuracy: 0.9439 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 30/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1706 - accuracy: 0.9387 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 31/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1451 - accuracy: 0.9455 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 32/1000
# 239/239 [==============================] - 3s 10ms/step - loss: 0.1554 - accuracy: 0.9366 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 33/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1204 - accuracy: 0.9523 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 34/1000
# 239/239 [==============================] - 3s 10ms/step - loss: 0.1187 - accuracy: 0.9586 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 35/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1136 - accuracy: 0.9528 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 36/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1192 - accuracy: 0.9570 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 37/1000
# 239/239 [==============================] - 3s 10ms/step - loss: 0.1307 - accuracy: 0.9528 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 38/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1216 - accuracy: 0.9565 - val_loss: 0.0030 - val_accuracy: 1.0000
# 15/15 [==============================] - 0s 9ms/step
# 7/7 [==============================] - 0s 8ms/step
# Final Test Accuracy: 0.9951219512195122
# Final Test Sensitivity: 0.9951219512195122
# Final Test Specificity: 0.998780487804878
# Final Test F1 Score: 0.9951219512195122
# Final training accuracy per fold: [0.9743186831474304, 0.9743186831474304, 0.9633123874664307, 0.9633123874664307, 0.9654088020324707, 0.9654088020324707, 0.9564989805221558, 0.9564989805221558]
# Final validation accuracy per fold: [1.0, 1.0, 1.0, 1.0]
# Final test accuracy per fold: [1.0, 1.0, 1.0, 0.9804878048780488, 1.0, 0.9951219512195122, 1.0, 0.9951219512195122]
# Average final training accuracy: 0.9648847132921219
# Average final validation accuracy: 1.0
# Average final test accuracy: 0.9963414634146341
# Final sensitivity per fold: [1.0, 0.9804878048780488, 0.9951219512195122, 0.9951219512195122]
# Final specificity per fold: [1.0, 0.9951219512195122, 0.998780487804878, 0.998780487804878]
# Final F1 score per fold: [1.0, 0.9804878048780488, 0.9951219512195122, 0.9951219512195122]
# Average final sensitivity: 0.9926829268292683
# Average final specificity: 0.9981707317073172
# Average final F1 score: 0.9926829268292683
# Epoch 1/1000
# 239/239 [==============================] - 9s 13ms/step - loss: 1.5411 - accuracy: 0.3092 - val_loss: 1.3009 - val_accuracy: 0.5597
# Epoch 2/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 1.1917 - accuracy: 0.5010 - val_loss: 0.8352 - val_accuracy: 0.7673
# Epoch 3/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.9321 - accuracy: 0.6200 - val_loss: 0.5348 - val_accuracy: 0.8407
# Epoch 4/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.7111 - accuracy: 0.7385 - val_loss: 0.3375 - val_accuracy: 0.9036
# Epoch 5/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.5462 - accuracy: 0.8124 - val_loss: 0.2545 - val_accuracy: 0.9476
# Epoch 6/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.4760 - accuracy: 0.8297 - val_loss: 0.1889 - val_accuracy: 0.9560
# Epoch 7/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.4613 - accuracy: 0.8270 - val_loss: 0.1495 - val_accuracy: 0.9560
# Epoch 8/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.4039 - accuracy: 0.8559 - val_loss: 0.1585 - val_accuracy: 0.9581
# Epoch 9/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.3417 - accuracy: 0.8831 - val_loss: 0.1276 - val_accuracy: 0.9623
# Epoch 10/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.3294 - accuracy: 0.8758 - val_loss: 0.1090 - val_accuracy: 0.9748
# Epoch 11/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.3072 - accuracy: 0.8836 - val_loss: 0.0958 - val_accuracy: 0.9706
# Epoch 12/1000
# 239/239 [==============================] - 3s 10ms/step - loss: 0.2829 - accuracy: 0.8947 - val_loss: 0.0915 - val_accuracy: 0.9727
# Epoch 13/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2577 - accuracy: 0.9041 - val_loss: 0.0747 - val_accuracy: 0.9769
# Epoch 14/1000
# 239/239 [==============================] - 3s 10ms/step - loss: 0.2680 - accuracy: 0.9020 - val_loss: 0.0734 - val_accuracy: 0.9811
# Epoch 15/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2457 - accuracy: 0.9078 - val_loss: 0.0642 - val_accuracy: 0.9811
# Epoch 16/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2335 - accuracy: 0.9177 - val_loss: 0.0572 - val_accuracy: 0.9853
# Epoch 17/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1960 - accuracy: 0.9303 - val_loss: 0.0499 - val_accuracy: 0.9916
# Epoch 18/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2129 - accuracy: 0.9219 - val_loss: 0.0381 - val_accuracy: 0.9895
# Epoch 19/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.2099 - accuracy: 0.9203 - val_loss: 0.0490 - val_accuracy: 0.9916
# Epoch 20/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1849 - accuracy: 0.9313 - val_loss: 0.0399 - val_accuracy: 0.9895
# Epoch 21/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1814 - accuracy: 0.9340 - val_loss: 0.0323 - val_accuracy: 0.9895
# Epoch 22/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1732 - accuracy: 0.9418 - val_loss: 0.0304 - val_accuracy: 0.9895
# Epoch 23/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1700 - accuracy: 0.9345 - val_loss: 0.0246 - val_accuracy: 0.9895
# Epoch 24/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1590 - accuracy: 0.9403 - val_loss: 0.0266 - val_accuracy: 0.9916
# Epoch 25/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1640 - accuracy: 0.9418 - val_loss: 0.0276 - val_accuracy: 0.9895
# Epoch 26/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1404 - accuracy: 0.9492 - val_loss: 0.0334 - val_accuracy: 0.9895
# Epoch 27/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1309 - accuracy: 0.9492 - val_loss: 0.0202 - val_accuracy: 0.9916
# Epoch 28/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1376 - accuracy: 0.9476 - val_loss: 0.0233 - val_accuracy: 0.9916
# Epoch 29/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1346 - accuracy: 0.9429 - val_loss: 0.0139 - val_accuracy: 0.9937
# Epoch 30/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1268 - accuracy: 0.9481 - val_loss: 0.0287 - val_accuracy: 0.9895
# Epoch 31/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1151 - accuracy: 0.9534 - val_loss: 0.0134 - val_accuracy: 0.9937
# Epoch 32/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1378 - accuracy: 0.9450 - val_loss: 0.0349 - val_accuracy: 0.9916
# Epoch 33/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1561 - accuracy: 0.9460 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 34/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1109 - accuracy: 0.9586 - val_loss: 0.0145 - val_accuracy: 0.9958
# Epoch 35/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1355 - accuracy: 0.9444 - val_loss: 0.0372 - val_accuracy: 0.9937
# Epoch 36/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1113 - accuracy: 0.9555 - val_loss: 0.0132 - val_accuracy: 0.9937
# Epoch 37/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.1299 - accuracy: 0.9507 - val_loss: 0.0246 - val_accuracy: 0.9916
# Epoch 38/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1013 - accuracy: 0.9596 - val_loss: 0.0111 - val_accuracy: 0.9979
# Epoch 39/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1017 - accuracy: 0.9586 - val_loss: 0.0164 - val_accuracy: 0.9937
# Epoch 40/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.1105 - accuracy: 0.9602 - val_loss: 0.0137 - val_accuracy: 0.9916
# Epoch 41/1000
# 239/239 [==============================] - 3s 12ms/step - loss: 0.0868 - accuracy: 0.9696 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 42/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.0997 - accuracy: 0.9628 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 43/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.0875 - accuracy: 0.9633 - val_loss: 0.0111 - val_accuracy: 0.9937
# Epoch 44/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.0994 - accuracy: 0.9602 - val_loss: 0.0333 - val_accuracy: 0.9937
# Epoch 45/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.0838 - accuracy: 0.9659 - val_loss: 0.0232 - val_accuracy: 0.9937
# Epoch 46/1000
# 239/239 [==============================] - 3s 13ms/step - loss: 0.1037 - accuracy: 0.9591 - val_loss: 0.0124 - val_accuracy: 0.9937
# Epoch 47/1000
# 239/239 [==============================] - 3s 11ms/step - loss: 0.0917 - accuracy: 0.9638 - val_loss: 0.0134 - val_accuracy: 0.9958
# 15/15 [==============================] - 0s 9ms/step
# 7/7 [==============================] - 0s 9ms/step
# Final Test Accuracy: 0.9902439024390244
# Final Test Sensitivity: 0.9902439024390244
# Final Test Specificity: 0.9975609756097562
# Final Test F1 Score: 0.9902439024390244
# Final training accuracy per fold: [0.9743186831474304, 0.9743186831474304, 0.9633123874664307, 0.9633123874664307, 0.9654088020324707, 0.9654088020324707, 0.9564989805221558, 0.9564989805221558, 0.9638364911079407, 0.9638364911079407]
# Final validation accuracy per fold: [1.0, 1.0, 1.0, 1.0, 0.9958071112632751]
# Final test accuracy per fold: [1.0, 1.0, 1.0, 0.9804878048780488, 1.0, 0.9951219512195122, 1.0, 0.9951219512195122, 0.9958071112632751, 0.9902439024390244]
# Average final training accuracy: 0.9646750688552856
# Average final validation accuracy: 0.999161422252655
# Average final test accuracy: 0.9956782721019373
# Final sensitivity per fold: [1.0, 0.9804878048780488, 0.9951219512195122, 0.9951219512195122, 0.9902439024390244]
# Final specificity per fold: [1.0, 0.9951219512195122, 0.998780487804878, 0.998780487804878, 0.9975609756097562]
# Final F1 score per fold: [1.0, 0.9804878048780488, 0.9951219512195122, 0.9951219512195122, 0.9902439024390244]
# Average final sensitivity: 0.9921951219512195
# Average final specificity: 0.9980487804878051
# Average final F1 score: 0.9921951219512195

# %%
# Define the input shape for the model
input_shape = train_data[0].shape

# %%
input_shape
# Out:
# (47, 1, 13)

# %%
    # Save the model after training
    model.save(f'model_fold_{fold+1}.h5')
